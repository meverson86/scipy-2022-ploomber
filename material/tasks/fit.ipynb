# %%
# Add description here
#

# %%
# Uncomment the next two lines to enable auto reloading for imported modules
# %load_ext autoreload
# %autoreload 2
# For more info, see:
# https://docs.ploomber.io/en/latest/user-guide/faq_index.html#auto-reloading-code-in-jupyter

# %%
import pickle
from pathlib import Path
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
# If this task has dependencies, list them them here
# (e.g. upstream = ['some_task']), otherwise leave as None.
upstream = ['train-test-split']

# This is a placeholder, leave it as None
product = None

# %%
# This cell was injected automatically based on your stated upstream dependencies (cell above) and pipeline.yaml preferences. It is temporary and will be removed when you save this notebook
upstream = {
    "train-test-split": {
        "y_train": "D:\\scipy2022\\scipy-2022-ploomber\\material\\output\\train-test-split-y_train.pkl",
        "y_test": "D:\\scipy2022\\scipy-2022-ploomber\\material\\output\\train-test-split-y_test.pkl",
        "X_train": "D:\\scipy2022\\scipy-2022-ploomber\\material\\output\\train-test-split-X_train.pkl",
        "X_test": "D:\\scipy2022\\scipy-2022-ploomber\\material\\output\\train-test-split-X_test.pkl",
        "nb": "D:\\scipy2022\\scipy-2022-ploomber\\material\\output\\train-test-split.ipynb",
    }
}
product = {"nb": "D:\\scipy2022\\scipy-2022-ploomber\\material\\output\\fit.html"}

# %%
X_test = pickle.loads(Path(upstream['train-test-split']['X_test']).read_bytes())
X_train = pickle.loads(Path(upstream['train-test-split']['X_train']).read_bytes())
y_test = pickle.loads(Path(upstream['train-test-split']['y_test']).read_bytes())
y_train = pickle.loads(Path(upstream['train-test-split']['y_train']).read_bytes())

# %%
# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)

# %%
y_pred = lr.predict(X_test)

# %%
# %%
sns.scatterplot(x=y_test, y=y_pred)
# Out:
# <AxesSubplot:xlabel='MedHouseVal'>

# %%
print('rerunning')
